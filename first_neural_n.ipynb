# %% [markdown]
# <a href="https://colab.research.google.com/github/sultanzada789/assignment/blob/main/first_neural_n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
print(tf.__version__)
# Out:
# 2.15.0

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.15.0
# Uninstalling tensorflow-2.15.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.10/dist-packages/tensorflow-2.15.0.dist-info/*
#     /usr/local/lib/python3.10/dist-packages/tensorflow/*
# Proceed (Y/n)? y
# y
#   Successfully uninstalled tensorflow-2.15.0

# %%
# !pip install tensorflow==2.8

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.8.0

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

# %%
# draw a sequential layer of nueral network
model=tf.keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
#COMPILE the model
model.compile(optimizer='sgd',loss='mean_squared_error')

# %%
# make numpy arry for model
xs=np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys=np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
#training the model
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 469ms/step - loss: 1.0357
# Epoch 2/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.9426
# Epoch 3/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.8668
# Epoch 4/500
# 1/1 [==============================] - 0s 9ms/step - loss: 0.8046
# Epoch 5/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7531
# Epoch 6/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.7101
# Epoch 7/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6739
# Epoch 8/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.6430
# Epoch 9/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.6164
# Epoch 10/500
# 1/1 [==============================] - 0s 10ms/step - loss: 0.5932
# Epoch 11/500
# 1/1 [==============================] - 0s 11ms/step - loss: 0.5728
# Epoch 12/500
# 1/1 [==============================] - 0s 12ms/step - loss: 0.5545
# ...

# %%
# pridicting the model
model.predict([10])
# Out:
# 1/1 [==============================] - 0s 105ms/step
# array([[18.986605]], dtype=float32)
